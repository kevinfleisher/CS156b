# %%
import numpy as np
import pandas as pd

# %%
file_path = '/Users/omidgolami/CS156b/Data/train.csv'
train_df = pd.read_csv(file_path)
train_df
# Out:
#         Unnamed: 0                                               Path     Sex  \
# 0                0            train/pid50512/study1/view1_frontal.jpg  Female
# 1                1            train/pid21580/study2/view1_frontal.jpg  Female
# 2                2            train/pid21580/study1/view1_frontal.jpg  Female
# 3                3            train/pid21580/study1/view2_lateral.jpg  Female
# 4                4            train/pid33839/study1/view1_frontal.jpg    Male
# ...            ...                                                ...     ...
# 178153      223409            train/pid16708/study2/view1_frontal.jpg    Male
# 178154      223410            train/pid16708/study1/view1_frontal.jpg    Male
# 178155      223411            train/pid32381/study1/view1_frontal.jpg  Female
# 178156      223412            train/pid25865/study1/view1_frontal.jpg  Female
# 178157      223413  CheXpert-v1.0/train/patient64540/study1/view1_...  Female
#
# ...

# %%
ratios = []
for col in train_df.columns[6:20]:
    num_nan = train_df[col].isna().sum()
    num_zeros = (train_df[col] == 0).sum()
    num_ones = (train_df[col] == 1).sum()
    num_minus_ones = (train_df[col] == -1).sum()
    total_rows = len(train_df)
    ratio_nan = num_nan / total_rows
    ratio_zero = num_zeros / total_rows
    ratio_ones = num_ones / total_rows
    ratio_minus_ones = num_minus_ones / total_rows
    ratios.append({
        'Column': col,
        'NaN Ratio': ratio_nan,
        '-1 Ratio': ratio_minus_ones,
        '0 Ratio': ratio_zero,
        '1 Ratio': ratio_ones
    })

ratios_df = pd.DataFrame(ratios)

ratios_df
# Out:
#                         Column  NaN Ratio  -1 Ratio   0 Ratio   1 Ratio
# 0                   No Finding   0.894431  0.000000  0.000000  0.105569
# 1   Enlarged Cardiomediastinum   0.782811  0.101842  0.073407  0.041940
# 2                 Cardiomegaly   0.770384  0.069113  0.047587  0.112917
# 3                 Lung Opacity   0.468090  0.028638  0.029805  0.473467
# 4                  Lung Lesion   0.943208  0.005439  0.009576  0.041778
# 5                        Edema   0.611861  0.091823  0.065655  0.230660
# 6                Consolidation   0.678224  0.128998  0.134740  0.058038
# 7                    Pneumonia   0.877059  0.011355  0.096398  0.015189
# 8                  Atelectasis   0.690095  0.003183  0.161817  0.144905
# 9                 Pneumothorax   0.647145  0.252254  0.021952  0.078649
# 10            Pleural Effusion   0.401037  0.154986  0.058661  0.385315
# 11               Pleural Other   0.969482  0.000674  0.013247  0.016598
# ...

# %%
file_path = '/Users/omidgolami/CS156b Data/data_subset/raw_train_images.npy'
img_name = np.load(file_path)

img_name
# Out:
# array(['/groups/CS156b/data/train/pid50512/study1/view1_frontal.jpg',
#        '/groups/CS156b/data/train/pid21580/study2/view1_frontal.jpg',
#        '/groups/CS156b/data/train/pid21580/study1/view1_frontal.jpg', ...,
#        '/groups/CS156b/data/train/pid16708/study1/view1_frontal.jpg',
#        '/groups/CS156b/data/train/pid32381/study1/view1_frontal.jpg',
#        '/groups/CS156b/data/train/pid25865/study1/view1_frontal.jpg'],
#       dtype='<U60')

# %%
path_to_label = dict(zip(img_name['path'], img_name['label']))
